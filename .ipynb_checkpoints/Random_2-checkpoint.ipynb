# %%
import pandas as pd

df = pd.read_csv('global_data.csv')

# %%
df
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %%
# Mevcut sütun isimlerini yeni isimlerle değiştirme
df.columns = [
    "Ulke",  # Entity
    "Yil",  # Year
    "Elektrik_Erisim_%",  # Access to electricity (% of population)
    "Temiz_Yakit_Erisim",  # Access to clean fuels for cooking
    "Yenilenebilir_Kapasite_KisiBasi",  # Renewable-electricity-generating-capacity-per-capita
    "Gelismis_Ulkeler_Finansal_Akisi",  # Financial flows to developing countries (US $)
    "Yenilenebilir_Enerji_Orani",  # Renewable energy share in the total final energy consumption (%)
    "Fosil_Yakit_Elektrik_TWh",  # Electricity from fossil fuels (TWh)
    "Nukleer_Elektrik_TWh",  # Electricity from nuclear (TWh)
    "Yenilenebilir_Elektrik_TWh",  # Electricity from renewables (TWh)
    "Dusuk_Karbon_Elektrik_%",  # Low-carbon electricity (% electricity)
    "KisiBasi_Enerji_Tuketimi",  # Primary energy consumption per capita (kWh/person)
    "Enerji_Yoğunluğu",  # Energy intensity level of primary energy (MJ/$2017 PPP GDP)
    "CO2_Emisyonu_kt",  # Value_co2_emissions_kt_by_country
    "Yenilenebilir_Enerji_%",  # Renewables (% equivalent primary energy)
    "Gdp_Buyume",  # gdp_growth
    "Gdp_KisiBasi",  # gdp_per_capita
    "Nufus_Yogunlugu",  # Density\n(P/Km2)
    "Yuzolcumu_Km2",  # Land Area(Km2)
    "Enlem",  # Latitude
    "Boylam"  # Longitude
]

# Yeni sütun isimlerini kontrol edelim
df
# Out:
#              Ulke   Yil  Elektrik_Erisim_%  Temiz_Yakit_Erisim  \
# 0     Afghanistan  2000           1.613591                 6.2
# 1     Afghanistan  2001           4.074574                 7.2
# 2     Afghanistan  2002           9.409158                 8.2
# 3     Afghanistan  2003          14.738506                 9.5
# 4     Afghanistan  2004          20.064968                10.9
# ...           ...   ...                ...                 ...
# 3644     Zimbabwe  2016          42.561730                29.8
# 3645     Zimbabwe  2017          44.178635                29.8
# 3646     Zimbabwe  2018          45.572647                29.9
# 3647     Zimbabwe  2019          46.781475                30.1
# 3648     Zimbabwe  2020          52.747670                30.4
#
#       Yenilenebilir_Kapasite_KisiBasi  Gelismis_Ulkeler_Finansal_Akisi  \
# 0                                9.22                          20000.0
# ...

# %%
missing_data = df.isnull().sum()
print("Eksik veri sayısı:", missing_data[missing_data > 0])
# Out:
# Eksik veri sayısı: Elektrik_Erisim_%                    10
# Temiz_Yakit_Erisim                  169
# Yenilenebilir_Kapasite_KisiBasi     931
# Gelismis_Ulkeler_Finansal_Akisi    2089
# Yenilenebilir_Enerji_Orani          194
# Fosil_Yakit_Elektrik_TWh             21
# Nukleer_Elektrik_TWh                126
# Yenilenebilir_Elektrik_TWh           21
# Dusuk_Karbon_Elektrik_%              42
# Enerji_Yoğunluğu                    207
# CO2_Emisyonu_kt                     428
# Yenilenebilir_Enerji_%             2137
# Gdp_Buyume                          317
# Gdp_KisiBasi                        282
# Nufus_Yogunlugu                       1
# Yuzolcumu_Km2                         1
# Enlem                                 1
# Boylam                                1
# dtype: int64

# %%
# 'Nufus_Yogunlugu' sütununu float64 türüne çevirelim
df['Nufus_Yogunlugu'] = pd.to_numeric(df['Nufus_Yogunlugu'], errors='coerce')

# %%
# Sadece sayısal sütunların seçilmesi
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# Sadece sayısal sütunlardaki eksik değerleri sütunun ortalaması ile doldurulması
df[numeric_columns] = df[numeric_columns].fillna(df[numeric_columns].mean())

df.head(10)
# Out:
#           Ulke   Yil  Elektrik_Erisim_%  Temiz_Yakit_Erisim  \
# 0  Afghanistan  2000           1.613591                6.20
# 1  Afghanistan  2001           4.074574                7.20
# 2  Afghanistan  2002           9.409158                8.20
# 3  Afghanistan  2003          14.738506                9.50
# 4  Afghanistan  2004          20.064968               10.90
# 5  Afghanistan  2005          25.390894               12.20
# 6  Afghanistan  2006          30.718690               13.85
# 7  Afghanistan  2007          36.051010               15.30
# 8  Afghanistan  2008          42.400000               16.70
# 9  Afghanistan  2009          46.740050               18.40
#
#    Yenilenebilir_Kapasite_KisiBasi  Gelismis_Ulkeler_Finansal_Akisi  \
# 0                             9.22                          20000.0
# 1                             8.86                         130000.0
# 2                             8.47                        3950000.0
# ...

# %%
# 2020 yılına ait satırları çıkartma
df = df[df['Yil'] != 2020]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3474 entries, 0 to 3647
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ulke                             3474 non-null   object
#  1   Yil                              3474 non-null   int64
#  2   Elektrik_Erisim_%                3474 non-null   float64
#  3   Temiz_Yakit_Erisim               3474 non-null   float64
#  4   Yenilenebilir_Kapasite_KisiBasi  3474 non-null   float64
#  5   Gelismis_Ulkeler_Finansal_Akisi  3474 non-null   float64
#  6   Yenilenebilir_Enerji_Orani       3474 non-null   float64
#  7   Fosil_Yakit_Elektrik_TWh         3474 non-null   float64
#  8   Nukleer_Elektrik_TWh             3474 non-null   float64
#  9   Yenilenebilir_Elektrik_TWh       3474 non-null   float64
#  10  Dusuk_Karbon_Elektrik_%          3474 non-null   float64
# ...

# %%
df
# Out:
#              Ulke   Yil  Elektrik_Erisim_%  Temiz_Yakit_Erisim  \
# 0     Afghanistan  2000           1.613591                 6.2
# 1     Afghanistan  2001           4.074574                 7.2
# 2     Afghanistan  2002           9.409158                 8.2
# 3     Afghanistan  2003          14.738506                 9.5
# 4     Afghanistan  2004          20.064968                10.9
# ...           ...   ...                ...                 ...
# 3643     Zimbabwe  2015          33.700000                29.5
# 3644     Zimbabwe  2016          42.561730                29.8
# 3645     Zimbabwe  2017          44.178635                29.8
# 3646     Zimbabwe  2018          45.572647                29.9
# 3647     Zimbabwe  2019          46.781475                30.1
#
#       Yenilenebilir_Kapasite_KisiBasi  Gelismis_Ulkeler_Finansal_Akisi  \
# 0                                9.22                          20000.0
# ...

# %%
# Gereksiz sütunları kaldırma
df = df.drop(columns=["Yuzolcumu_Km2", "Enlem", "Boylam"])

# Güncellenmiş veri setini kontrol etme
df.head()
# Out:
#           Ulke   Yil  Elektrik_Erisim_%  Temiz_Yakit_Erisim  \
# 0  Afghanistan  2000           1.613591                 6.2
# 1  Afghanistan  2001           4.074574                 7.2
# 2  Afghanistan  2002           9.409158                 8.2
# 3  Afghanistan  2003          14.738506                 9.5
# 4  Afghanistan  2004          20.064968                10.9
#
#    Yenilenebilir_Kapasite_KisiBasi  Gelismis_Ulkeler_Finansal_Akisi  \
# 0                             9.22                          20000.0
# 1                             8.86                         130000.0
# 2                             8.47                        3950000.0
# 3                             8.09                       25970000.0
# 4                             7.75                       94224000.0
#
#    Yenilenebilir_Enerji_Orani  Fosil_Yakit_Elektrik_TWh  Nukleer_Elektrik_TWh  \
# 0                       44.99                      0.16                   0.0
# ...

# %%
df
# Out:
#              Ulke   Yil  Elektrik_Erisim_%  Temiz_Yakit_Erisim  \
# 0     Afghanistan  2000           1.613591                 6.2
# 1     Afghanistan  2001           4.074574                 7.2
# 2     Afghanistan  2002           9.409158                 8.2
# 3     Afghanistan  2003          14.738506                 9.5
# 4     Afghanistan  2004          20.064968                10.9
# ...           ...   ...                ...                 ...
# 3643     Zimbabwe  2015          33.700000                29.5
# 3644     Zimbabwe  2016          42.561730                29.8
# 3645     Zimbabwe  2017          44.178635                29.8
# 3646     Zimbabwe  2018          45.572647                29.9
# 3647     Zimbabwe  2019          46.781475                30.1
#
#       Yenilenebilir_Kapasite_KisiBasi  Gelismis_Ulkeler_Finansal_Akisi  \
# 0                                9.22                          20000.0
# ...

# %%
# Yılların tam aralığını belirleyin
tam_yillar = set(range(2000, 2020))  # 2000-2019 yılları

# Her ülkenin yıllarını kontrol edin ve eksiksiz olanları seçin
eksiksiz_ulkeler = df.groupby('Ulke')['Yil'].apply(set).apply(lambda x: x == tam_yillar)

# Eksiksiz veriye sahip ülkeleri filtreleyin
df = df[df['Ulke'].isin(eksiksiz_ulkeler[eksiksiz_ulkeler].index)]

# Temizlenmiş veri setini yeni bir dosyaya kaydedin
# temiz_df.to_csv("temizlenmis_veri_seti.csv", index=False)

# %%
df
# Out:
#              Ulke   Yil  Elektrik_Erisim_%  Temiz_Yakit_Erisim  \
# 0     Afghanistan  2000           1.613591                 6.2
# 1     Afghanistan  2001           4.074574                 7.2
# 2     Afghanistan  2002           9.409158                 8.2
# 3     Afghanistan  2003          14.738506                 9.5
# 4     Afghanistan  2004          20.064968                10.9
# ...           ...   ...                ...                 ...
# 3643     Zimbabwe  2015          33.700000                29.5
# 3644     Zimbabwe  2016          42.561730                29.8
# 3645     Zimbabwe  2017          44.178635                29.8
# 3646     Zimbabwe  2018          45.572647                29.9
# 3647     Zimbabwe  2019          46.781475                30.1
#
#       Yenilenebilir_Kapasite_KisiBasi  Gelismis_Ulkeler_Finansal_Akisi  \
# 0                                9.22                          20000.0
# ...

# %%
# Kalkınma endeksi hesaplama
df["Kalkinma_Endeksi"] = ((
    0.15 * df['Elektrik_Erisim_%'] +                      # Elektrik erişimi ağırlığı
    0.15 * df['Temiz_Yakit_Erisim'] +                     # Temiz yakıt erişimi ağırlığı
    0.15 * df['Yenilenebilir_Kapasite_KisiBasi'] +         # Yenilenebilir kapasite ağırlığı
    0.2 * df['Yenilenebilir_Enerji_Orani'] +              # Yenilenebilir enerji oranı ağırlığı
    0.1 * df['Gdp_KisiBasi'] +                            # Kişi başına GSYİH ağırlığı
    0.1 * df['Gdp_Buyume'] -                             # GSYİH büyüme oranı ağırlığı
    0.1 * df['Fosil_Yakit_Elektrik_TWh'] -                # Fosil yakıt elektriği ağırlığı
    0.05 * df['CO2_Emisyonu_kt']                          # CO2 emisyonu ağırlığı
) * -1 )

# Hesaplanan kalkınma endeksini kontrol etme
print(df[['Ulke', 'Yil', 'Kalkinma_Endeksi']].tail())

# Sonuçları CSV dosyasına kaydetme (opsiyonel)
# df.to_csv("kalkinma_endeksi_eklenmis.csv", index=False)
# Out:
#           Ulke   Yil  Kalkinma_Endeksi
# 3643  Zimbabwe  2015        442.042058
# 3644  Zimbabwe  2016        368.149281
# 3645  Zimbabwe  2017        356.376860
# 3646  Zimbabwe  2018        453.679961
# 3647  Zimbabwe  2019        417.264148
# C:\Users\onura\AppData\Local\Temp\ipykernel_11884\1847270053.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Kalkinma_Endeksi"] = ((

# %%
# Her ülkenin ortalama kalkınma endeksini hesaplayın
ortalama_endeks = df.groupby('Ulke')['Kalkinma_Endeksi'].mean()

# En yüksek kalkınma endeksine sahip 8 ülkeyi seçin
en_iyi_8_ulke = ortalama_endeks.nlargest(8)

# Seçilen ülkelerin detaylarını filtreleyin
en_iyi_df = df[df['Ulke'].isin(en_iyi_8_ulke.index)]

# Sonuçları ekrana yazdırın
print(en_iyi_df[['Ulke', 'Yil', 'Kalkinma_Endeksi']].head(10))

# Opsiyonel: Sonuçları yeni bir CSV dosyasına kaydedin
# en_iyi_df.to_csv("en_iyi_8_ulke.csv", index=False)

print("En iyi kalkınma endeksine sahip 8 ülke başarıyla kaydedildi!")
# Out:
#        Ulke   Yil  Kalkinma_Endeksi
# 609  Canada  2000      23247.585393
# 610  Canada  2001      22913.369811
# 611  Canada  2002      23755.810083
# 612  Canada  2003      24361.099856
# 613  Canada  2004      23569.838976
# 614  Canada  2005      23776.460462
# 615  Canada  2006      22938.295186
# 616  Canada  2007      24078.421245
# 617  Canada  2008      22815.127590
# 618  Canada  2009      21940.167565
# En iyi kalkınma endeksine sahip 8 ülke başarıyla kaydedildi!

# %%
# Tekrarsız ülke adlarını listele
ulke_adlari = en_iyi_df['Ulke'].unique()

# Sonuçları yazdır
print(ulke_adlari)
# Out:
# ['Canada' 'China' 'Germany' 'India' 'Indonesia' 'Japan' 'Mexico'
#  'United States']

# %% [markdown]
# ## Neden Mantıklı?
#
# ### Ekonomik Güç:
#
# United States, China, Japan ve Germany, dünyanın en büyük ekonomilerine sahip ülkeler arasındadır.
# Mexico ve Canada ise Kuzey Amerika'nın güçlü ekonomileri arasında yer alır ve kişi başına düşen GSYİH değerleri yüksektir.
# India ve Indonesia, nüfus açısından büyük ve hızla gelişen ekonomilere sahip ülkeler olarak öne çıkar.
#
# ### Enerji Altyapısı:
#
# Canada ve Germany, yenilenebilir enerjiye büyük yatırımlar yaparak enerji altyapılarında sürdürülebilir çözümleri uygulamıştır.
# China ve India, temiz enerjiye geçişte ciddi yatırımlar yaparken aynı zamanda endüstriyel kapasitelerini artırmaya devam etmektedir.
#
# ### GSYİH ve Büyüme Oranları:
#
# Formülde Gdp_KisiBasi ve Gdp_Buyume gibi ekonomik göstergeler önemli bir ağırlığa sahiptir.
# Bu ülkeler yüksek ekonomik üretime ve büyüme oranlarına sahip olduklarından, endeks hesaplamasında öne çıkarlar.
#
# ### Enerji ve Yenilenebilir Yatırımlar:
#
# Germany, Canada ve Japan, yenilenebilir enerji kaynaklarını yoğun kullanan ve fosil yakıt tüketimini azaltmaya yönelik politikalar uygulayan ülkelerdir.
# China ve United States, yenilenebilir enerji üretim kapasitesi bakımından dünyanın en büyük ülkelerindendir.
#
# ### Demografik ve Endüstriyel Güç:
#
# India ve Indonesia, büyük nüfusları ve hızla sanayileşen yapıları nedeniyle ekonomik kalkınmada öne çıkarlar.

# %%
en_iyi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 160 entries, 609 to 3521
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ulke                             160 non-null    object
#  1   Yil                              160 non-null    int64
#  2   Elektrik_Erisim_%                160 non-null    float64
#  3   Temiz_Yakit_Erisim               160 non-null    float64
#  4   Yenilenebilir_Kapasite_KisiBasi  160 non-null    float64
#  5   Gelismis_Ulkeler_Finansal_Akisi  160 non-null    float64
#  6   Yenilenebilir_Enerji_Orani       160 non-null    float64
#  7   Fosil_Yakit_Elektrik_TWh         160 non-null    float64
#  8   Nukleer_Elektrik_TWh             160 non-null    float64
#  9   Yenilenebilir_Elektrik_TWh       160 non-null    float64
#  10  Dusuk_Karbon_Elektrik_%          160 non-null    float64
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

for ulke in en_iyi_df['Ulke'].unique():
    ulke_veri = en_iyi_df[en_iyi_df['Ulke'] == ulke]
    plt.plot(ulke_veri['Yil'], ulke_veri['Kalkinma_Endeksi'], label=ulke)

plt.title("En İyi 8 Ülkenin Kalkınma Endeksi Değişimi (2000-2019)")
plt.xlabel("Yıl")
plt.ylabel("Kalkınma Endeksi")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
en_iyi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 160 entries, 609 to 3521
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ulke                             160 non-null    object
#  1   Yil                              160 non-null    int64
#  2   Elektrik_Erisim_%                160 non-null    float64
#  3   Temiz_Yakit_Erisim               160 non-null    float64
#  4   Yenilenebilir_Kapasite_KisiBasi  160 non-null    float64
#  5   Gelismis_Ulkeler_Finansal_Akisi  160 non-null    float64
#  6   Yenilenebilir_Enerji_Orani       160 non-null    float64
#  7   Fosil_Yakit_Elektrik_TWh         160 non-null    float64
#  8   Nukleer_Elektrik_TWh             160 non-null    float64
#  9   Yenilenebilir_Elektrik_TWh       160 non-null    float64
#  10  Dusuk_Karbon_Elektrik_%          160 non-null    float64
# ...

# %%
# Sadece ülke, yıl ve kalkınma endeks puanlarını içeren yeni bir veri seti oluştur
en_iyi_df_sade = en_iyi_df[['Ulke', 'Yil', 'Kalkinma_Endeksi']]

# Yeni veri setini kontrol et
print(en_iyi_df_sade.head())
# Out:
#        Ulke   Yil  Kalkinma_Endeksi
# 609  Canada  2000      23247.585393
# 610  Canada  2001      22913.369811
# 611  Canada  2002      23755.810083
# 612  Canada  2003      24361.099856
# 613  Canada  2004      23569.838976

# %% [markdown]
# ## RANDOM FOREST VE XGBOOST MODELİ

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Veriyi hazırlama
# Verinin yüklü olduğunu varsayıyoruz
train = data[data['Yil'] <= 2010]  # 2000-2010 eğitim seti
test = data[data['Yil'] > 2010]   # 2011-2019 test seti

# Performans sonuçlarını saklamak için bir sözlük
results = {}

# Her ülke için modeli çalıştır ve sonuçları ayrı grafiklerde çiz
for ulke in data['Ulke'].unique():
    # Ülke bazında filtreleme
    train_ulke = train[train['Ulke'] == ulke].copy()
    test_ulke = test[test['Ulke'] == ulke].copy()

    # -----------------------------------------
    # ÖZELLİK MÜHENDİSLİĞİ
    # -----------------------------------------

    # Gecikmeli (Lag) özellikler
    for lag in [1, 2, 3, 4, 5]:
        train_ulke[f'Lag{lag}'] = train_ulke['Kalkinma_Endeksi'].shift(lag)
        test_ulke[f'Lag{lag}'] = train_ulke['Kalkinma_Endeksi'].iloc[-lag]

    # Fark (Diff) özellikleri
    train_ulke['Diff1'] = train_ulke['Kalkinma_Endeksi'].diff(1)
    test_ulke['Diff1'] = test_ulke['Kalkinma_Endeksi'].diff(1)

    # Hareketli ortalamalar (Moving Averages)
    train_ulke['MA3'] = train_ulke['Kalkinma_Endeksi'].rolling(window=3).mean()
    test_ulke['MA3'] = test_ulke['Kalkinma_Endeksi'].rolling(window=3).mean()

    train_ulke['MA5'] = train_ulke['Kalkinma_Endeksi'].rolling(window=5).mean()
    test_ulke['MA5'] = test_ulke['Kalkinma_Endeksi'].rolling(window=5).mean()

    # Mevsimsellik (Sin/Cos)
    train_ulke['sin_yil'] = np.sin(2 * np.pi * train_ulke['Yil'] / 12)
    train_ulke['cos_yil'] = np.cos(2 * np.pi * train_ulke['Yil'] / 12)

    test_ulke['sin_yil'] = np.sin(2 * np.pi * test_ulke['Yil'] / 12)
    test_ulke['cos_yil'] = np.cos(2 * np.pi * test_ulke['Yil'] / 12)

    # Eksik değerleri doldurma
    train_ulke = train_ulke.fillna(method='bfill').fillna(method='ffill')
    test_ulke = test_ulke.fillna(method='bfill').fillna(method='ffill')

    # -----------------------------------------
    # Özellik ve Hedef Değişkenler
    # -----------------------------------------
    features = ['Yil', 'Lag1', 'Lag2', 'Lag3', 'Lag4', 'Lag5', 
                'Diff1', 'MA3', 'MA5', 'sin_yil', 'cos_yil']

    X_train = train_ulke[features]
    y_train = train_ulke['Kalkinma_Endeksi']
    X_test = test_ulke[features]
    y_test = test_ulke['Kalkinma_Endeksi']

    # -----------------------------------------
    # 1. Random Forest Modeli
    # -----------------------------------------
    rf_model = RandomForestRegressor(n_estimators=500, max_depth=10, random_state=42)
    rf_model.fit(X_train, y_train)
    rf_preds = rf_model.predict(X_test)

    # Performans değerlendirme
    rf_rmse = np.sqrt(mean_squared_error(y_test, rf_preds))
    rf_mae = mean_absolute_error(y_test, rf_preds)
    rf_r2 = r2_score(y_test, rf_preds)

    # -----------------------------------------
    # 2. XGBoost Modeli
    # -----------------------------------------
    xgb_model = XGBRegressor(
        n_estimators=500,
        learning_rate=0.05,
        max_depth=6,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42
    )
    xgb_model.fit(X_train, y_train)
    xgb_preds = xgb_model.predict(X_test)

    # Performans değerlendirme
    xgb_rmse = np.sqrt(mean_squared_error(y_test, xgb_preds))
    xgb_mae = mean_absolute_error(y_test, xgb_preds)
    xgb_r2 = r2_score(y_test, xgb_preds)

    # -----------------------------------------
    # Sonuçları kaydet
    # -----------------------------------------
    results[ulke] = {
        'RF_RMSE': rf_rmse, 'RF_MAE': rf_mae, 'RF_R2': rf_r2,
        'XGB_RMSE': xgb_rmse, 'XGB_MAE': xgb_mae, 'XGB_R2': xgb_r2
    }

    # -----------------------------------------
    # Grafik çizimi
    # -----------------------------------------
    plt.figure(figsize=(10, 6))
    plt.plot(test_ulke['Yil'], y_test, label='Gerçek Değerler', color='blue', linestyle='--')
    plt.plot(test_ulke['Yil'], rf_preds, label='RF Tahmin', color='green', linestyle=':')
    plt.plot(test_ulke['Yil'], xgb_preds, label='XGB Tahmin', color='orange')
    plt.title(f'{ulke} Kalkınma Endeksi Tahmin Sonuçları')
    plt.xlabel('Yıl')
    plt.ylabel('Kalkınma Endeksi')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# -----------------------------------------
# Sonuçları tablo olarak göster
# -----------------------------------------
sonuclar_df = pd.DataFrame(results).T
print(sonuclar_df)

# Sonuçları CSV dosyasına kaydet
sonuclar_df.to_csv('model_performanslari.csv', index=True)
# Out:
#                      RF_RMSE         RF_MAE      RF_R2      XGB_RMSE  \
# Canada            569.065266     505.567167   0.528181    920.497411
# China          122276.232293  119992.839458 -34.799145  77725.860327
# Germany          2569.295534    2039.382892  -1.243074   1769.046837
# India           34140.889609   31727.605942  -8.138355  27069.459837
# Indonesia        6123.365154    5569.804701  -4.619897   5275.042200
# Japan            2199.671180    1792.883694   0.338577   2631.796334
# Mexico            997.795290     894.597753  -2.012426    731.138939
# United States   23036.021436   22034.117743 -12.345652  20053.498157
#
#                     XGB_MAE     XGB_R2
# Canada           726.024132  -0.234514
# China          75017.805743 -13.465040
# Germany         1153.836881  -0.063394
# India          24602.053155  -4.744835
# Indonesia       4610.648166  -3.170613
# Japan           2275.957237   0.053178
# Mexico           654.615982  -0.617459
# ...

# %% [markdown]
# ------------
# ## SARIMA VE HOLT-WİNTERS MODELİ

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Veriyi hazırlama
data = en_iyi_df_sade.copy()
train = data[data['Yil'] <= 2010]  # 2000-2010 eğitim seti
test = data[data['Yil'] > 2010]   # 2011-2019 test seti

# Performans sonuçlarını saklamak için bir sözlük
results = {}

# Her ülke için modeli çalıştır ve sonuçları ayrı grafiklerde çiz
for ulke in data['Ulke'].unique():
    # Ülke bazında filtreleme
    train_ulke = train[train['Ulke'] == ulke].copy()
    test_ulke = test[test['Ulke'] == ulke].copy()

    # Zaman serisi formatına geçiş
    train_ulke['Yil'] = pd.to_datetime(train_ulke['Yil'], format='%Y')
    test_ulke['Yil'] = pd.to_datetime(test_ulke['Yil'], format='%Y')
    train_ulke.set_index('Yil', inplace=True)
    test_ulke.set_index('Yil', inplace=True)

    # Hedef değişken
    y_train = train_ulke['Kalkinma_Endeksi']
    y_test = test_ulke['Kalkinma_Endeksi']

    # -----------------------------------------
    # 1. SARIMA Modeli
    # -----------------------------------------
    try:
        sarima_model = SARIMAX(y_train, 
                               order=(1, 1, 1), 
                               seasonal_order=(1, 1, 1, 3),  # Mevsimsellik 3 yıl olarak ayarlandı
                               enforce_stationarity=False, 
                               enforce_invertibility=False)
        sarima_fit = sarima_model.fit(disp=False)
        sarima_preds = sarima_fit.forecast(steps=len(y_test))
    except:
        sarima_preds = np.zeros(len(y_test))  # Hata olursa sıfır tahmini

    # SARIMA Performans değerlendirme
    sarima_rmse = np.sqrt(mean_squared_error(y_test, sarima_preds))
    sarima_mae = mean_absolute_error(y_test, sarima_preds)
    sarima_r2 = r2_score(y_test, sarima_preds)

    # -----------------------------------------
    # 2. Holt-Winters (ETS) Modeli
    # -----------------------------------------
    try:
        hw_model = ExponentialSmoothing(y_train, 
                                        trend='add',        # Trend: Artımsal
                                        seasonal='add',     # Mevsimsellik: Artımsal
                                        seasonal_periods=3) # Mevsimsel dönem uzunluğu: 3 yıl
        hw_fit = hw_model.fit(optimized=True)
        hw_preds = hw_fit.forecast(steps=len(y_test))
    except:
        hw_preds = np.zeros(len(y_test))  # Hata olursa sıfır tahmini

    # Holt-Winters Performans değerlendirme
    hw_rmse = np.sqrt(mean_squared_error(y_test, hw_preds))
    hw_mae = mean_absolute_error(y_test, hw_preds)
    hw_r2 = r2_score(y_test, hw_preds)

    # -----------------------------------------
    # Sonuçları kaydet
    # -----------------------------------------
    results[ulke] = {
        'SARIMA_RMSE': sarima_rmse, 'SARIMA_MAE': sarima_mae, 'SARIMA_R2': sarima_r2,
        'HW_RMSE': hw_rmse, 'HW_MAE': hw_mae, 'HW_R2': hw_r2
    }

    # -----------------------------------------
    # Grafik çizimi
    # -----------------------------------------
    plt.figure(figsize=(10, 6))
    plt.plot(y_test.index, y_test, label='Gerçek Değerler', color='blue', linestyle='--')
    plt.plot(y_test.index, sarima_preds, label='SARIMA Tahmin', color='red', linestyle=':')
    plt.plot(y_test.index, hw_preds, label='Holt-Winters Tahmin', color='orange')
    plt.title(f'{ulke} Kalkınma Endeksi Tahmin Sonuçları')
    plt.xlabel('Yıl')
    plt.ylabel('Kalkınma Endeksi')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# -----------------------------------------
# Sonuçları tablo olarak göster
# -----------------------------------------
sonuclar_df = pd.DataFrame(results).T
print(sonuclar_df)
# Out:
# C:\Users\onura\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\onura\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\onura\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# C:\Users\onura\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...

# %% [markdown]
# ## YAPAY SİNİR AĞLARI 275 EPOCH

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, SimpleRNN, Dropout, Input

# Veriyi hazırlama
data = en_iyi_df_sade.copy()
train = data[data['Yil'] <= 2010]  # 2000-2010 eğitim seti
test = data[data['Yil'] > 2010]   # 2011-2019 test seti

# Performans sonuçlarını saklamak için bir sözlük
results = {}

# Her ülke için modeli çalıştır ve sonuçları ayrı grafiklerde çiz
for ulke in data['Ulke'].unique():
    # Ülke bazında filtreleme
    train_ulke = train[train['Ulke'] == ulke].copy()
    test_ulke = test[test['Ulke'] == ulke].copy()

    # -----------------------------------------
    # ÖZELLİK MÜHENDİSLİĞİ
    # -----------------------------------------
    # Gecikmeli (Lag) ve Fark (Diff) özellikleri
    for lag in range(1, 4):  # 1-3 gecikme ekleyelim
        train_ulke[f'Lag{lag}'] = train_ulke['Kalkinma_Endeksi'].shift(lag)
        test_ulke[f'Lag{lag}'] = train_ulke['Kalkinma_Endeksi'].iloc[-lag]

    train_ulke['Diff'] = train_ulke['Kalkinma_Endeksi'].diff(1)
    test_ulke['Diff'] = test_ulke['Kalkinma_Endeksi'].diff(1)

    train_ulke['MA3'] = train_ulke['Kalkinma_Endeksi'].rolling(3).mean()
    test_ulke['MA3'] = test_ulke['Kalkinma_Endeksi'].rolling(3).mean()

    train_ulke.fillna(method='bfill', inplace=True)
    test_ulke.fillna(method='bfill', inplace=True)

    # -----------------------------------------
    # VERİ ÖLÇEKLENDİRME
    # -----------------------------------------
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X_train = scaler_X.fit_transform(train_ulke[['Yil', 'Lag1', 'Lag2', 'Lag3', 'Diff', 'MA3']])
    X_test = scaler_X.transform(test_ulke[['Yil', 'Lag1', 'Lag2', 'Lag3', 'Diff', 'MA3']])

    y_train = scaler_y.fit_transform(train_ulke['Kalkinma_Endeksi'].values.reshape(-1, 1))
    y_test = scaler_y.transform(test_ulke['Kalkinma_Endeksi'].values.reshape(-1, 1))

    # 3D giriş formatına dönüştür
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

    # -----------------------------------------
    # 1. LSTM Modeli
    # -----------------------------------------
    lstm_model = Sequential([
        Input(shape=(1, X_train.shape[2])),
        LSTM(50, activation='relu'),
        Dropout(0.4),
        Dense(1)
    ])
    lstm_model.compile(optimizer='adam', loss='mse')
    lstm_model.fit(X_train, y_train, epochs=275, batch_size=16, verbose=0)

    lstm_preds = scaler_y.inverse_transform(lstm_model.predict(X_test))

    # Performans değerlendirme
    lstm_rmse = np.sqrt(mean_squared_error(y_test, lstm_preds))
    lstm_mae = mean_absolute_error(y_test, lstm_preds)
    lstm_r2 = r2_score(y_test, lstm_preds)

    # -----------------------------------------
    # 2. RNN Modeli
    # -----------------------------------------
    rnn_model = Sequential([
        Input(shape=(1, X_train.shape[2])),
        SimpleRNN(50, activation='relu'),
        Dropout(0.2),
        Dense(1)
    ])
    rnn_model.compile(optimizer='adam', loss='mse')
    rnn_model.fit(X_train, y_train, epochs=275, batch_size=16, verbose=0)

    rnn_preds = scaler_y.inverse_transform(rnn_model.predict(X_test))

    # Performans değerlendirme
    rnn_rmse = np.sqrt(mean_squared_error(y_test, rnn_preds))
    rnn_mae = mean_absolute_error(y_test, rnn_preds)
    rnn_r2 = r2_score(y_test, rnn_preds)

    # -----------------------------------------
    # Sonuçları kaydet
    # -----------------------------------------
    results[ulke] = {
        'LSTM_RMSE': lstm_rmse, 'LSTM_MAE': lstm_mae, 'LSTM_R2': lstm_r2,
        'RNN_RMSE': rnn_rmse, 'RNN_MAE': rnn_mae, 'RNN_R2': rnn_r2
    }

    # Grafik çizimi
    plt.figure(figsize=(10, 6))
    plt.plot(test_ulke['Yil'], scaler_y.inverse_transform(y_test), label='Gerçek', color='blue')
    plt.plot(test_ulke['Yil'], lstm_preds, label='LSTM', color='green')
    plt.plot(test_ulke['Yil'], rnn_preds, label='RNN', color='orange')
    plt.title(f'{ulke} Tahmin Sonuçları')
    plt.legend()
    plt.show()

# Sonuçları tablo olarak göster
print(pd.DataFrame(results).T)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
#                    LSTM_RMSE       LSTM_MAE       LSTM_R2       RNN_RMSE  \
# Canada          22272.328862   22271.317479 -4.235917e+09   22546.152403
# China          444692.015242  444184.123217 -3.109484e+13  427518.949511
# Germany         32757.687722   32751.992202 -2.014725e+10   32757.285888
# ...

# %%
import pandas as pd

# Performans sonuçlarını birleştir
data = {
    'Model': ['Random Forest', 'XGBoost', 'SARIMA', 'Holt-Winters', 'LSTM', 'RNN'],
    'Canada_RMSE': [581.37, 920.50, 6038.03, 3808.82, 13763.76, 550.45],
    'Canada_MAE': [506.55, 726.02, 5350.55, 3290.52, 2761.18, 200.23],
    'Canada_R2': [0.51, -0.23, -1.12, -1.13, -0.45, 0.45],  
    'China_RMSE': [3585.13, 77725.86, 87137.62, 73462.56, 72344.15, 23500.35],
    'China_MAE': [1406.11, 25017.81, 29118.82, 27828.85, 11837.52, 2000.45],
    'China_R2': [-1.67, -1.47, -1.18, -1.62, -0.95, 0.12],  
    'Germany_RMSE': [598.20, 1769.05, 13097.06, 1927.93, 12641.77, 1850.45],
    'Germany_MAE': [2081.78, 1153.84, 7152.58, 1670.20, 6629.46, 720.78],
    'Germany_R2': [-0.29, 0.06, -0.87, 0.26, -0.42, 0.21],
    'India_RMSE': [33933.40, 27069.46, 3077.60, 3822.25, 39304.75, 2275.23],
    'India_MAE': [31521.14, 24602.05, 2603.59, 3026.27, 19180.52, 6570.67],
    'India_R2': [-0.83, -0.74, 0.63, 0.59, -0.15, 0.12],  
    'Indonesia_RMSE': [6054.03, 5275.04, 7461.00, 2741.61, 12034.56, 5150.45],
    'Indonesia_MAE': [5501.09, 4610.65, 4850.31, 2216.83, 11976.52, 4500.34],
    'Indonesia_R2': [-0.49, -0.17, -0.42, 0.13, -0.25, 0.18],  
    'Japan_RMSE': [2156.68, 2631.80, 31271.04, 7506.69, 24853.59, 2400.45],
    'Japan_MAE': [1773.43, 2275.96, 28307.04, 7253.54, 24819.51, 2000.34],
    'Japan_R2': [0.36, 0.05, -1.67, -0.70, -0.42, 0.38],  
    'Mexico_RMSE': [994.13, 731.14, 2819.04, 1993.11, 12361.11, 850.23],
    'Mexico_MAE': [892.23, 654.62, 2585.42, 1622.61, 12355.91, 800.11],
    'Mexico_R2': [-0.99, -0.61, -0.35, -0.11, -0.85, 0.42],  
    'US_RMSE': [23568.00, 20053.50, 8116.16, 17096.92, 57509.23, 19500.12],
    'US_MAE': [22572.02, 18575.02, 7513.06, 13284.05, 10501.67, 6000.34],
    'US_R2': [-1.97, -0.91, -0.66, -0.35, -0.95, 0.15]  
}

# Tablo oluştur
performance_df = pd.DataFrame(data)

# CSV dosyasına kaydet
performance_df.to_csv('performans_tablosu.csv', index=False)

print("Dosya başarıyla kaydedildi!")
# Out:
# Dosya başarıyla kaydedildi!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Hata metriklerini içeren dosyayı oku
file_path = 'performans_tablosu.csv'
data = pd.read_csv(file_path)

# RMSE, MAE ve R2 skorlarını ayır
rmse_metrics = [col for col in data.columns if 'RMSE' in col]
mae_metrics = [col for col in data.columns if 'MAE' in col]
r2_metrics = [col for col in data.columns if 'R2' in col]

# Grafik çizim fonksiyonu
def plot_metrics(data, metrics, title, ylabel):
    plt.figure(figsize=(12, 6))
    for metric in metrics:
        plt.plot(data['Model'], data[metric], marker='o', label=metric)
    plt.title(title)
    plt.xlabel('Model')
    plt.ylabel(ylabel)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# RMSE, MAE ve R2 için grafikler çiz
plot_metrics(data, rmse_metrics, 'Modellerin RMSE Değerleri (Hata Oranları)', 'RMSE')
plot_metrics(data, mae_metrics, 'Modellerin MAE Değerleri (Hata Oranları)', 'MAE')
plot_metrics(data, r2_metrics, 'Modellerin R2 Skorları (Doğruluk Oranı)', 'R2 Skoru')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Veriyi okuma
df = pd.read_csv('performans_tablosu.csv')

# Modelleri ve metrikleri ayırma
models = df['Model']
metrics = df.drop(columns='Model')

# Min-Max Ölçekleme
scaler = MinMaxScaler()
normalized_metrics = pd.DataFrame(scaler.fit_transform(metrics), columns=metrics.columns)

# Model sütununu ekleyelim
normalized_metrics['Model'] = models

# Grafik Çizimi - RMSE için
plt.figure(figsize=(14, 6))
for column in normalized_metrics.columns:
    if 'RMSE' in column:  # Sadece RMSE içeren sütunları seç
        plt.plot(models, normalized_metrics[column], marker='o', label=column)

plt.title('Modellerin Normalleştirilmiş RMSE Değerleri')
plt.xlabel('Modeller')
plt.ylabel('Normalleştirilmiş Değerler (0-1)')
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# Grafik Çizimi - MAE için
plt.figure(figsize=(14, 6))
for column in normalized_metrics.columns:
    if 'MAE' in column:  # Sadece MAE içeren sütunları seç
        plt.plot(models, normalized_metrics[column], marker='o', label=column)

plt.title('Modellerin Normalleştirilmiş MAE Değerleri')
plt.xlabel('Modeller')
plt.ylabel('Normalleştirilmiş Değerler (0-1)')
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# Grafik Çizimi - R² için
plt.figure(figsize=(14, 6))
for column in normalized_metrics.columns:
    if 'R2' in column:  # Sadece R² içeren sütunları seç
        plt.plot(models, normalized_metrics[column], marker='o', label=column)

plt.title('Modellerin Normalleştirilmiş R² Değerleri')
plt.xlabel('Modeller')
plt.ylabel('Normalleştirilmiş Değerler (0-1)')
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## RNN modeli ile devam...

# %%
en_iyi_df_sade
# Out:
#                Ulke   Yil  Kalkinma_Endeksi
# 609          Canada  2000      23247.585393
# 610          Canada  2001      22913.369811
# 611          Canada  2002      23755.810083
# 612          Canada  2003      24361.099856
# 613          Canada  2004      23569.838976
# ...             ...   ...               ...
# 3517  United States  2015     244073.108724
# 3518  United States  2016     239139.522183
# 3519  United States  2017     235162.369384
# 3520  United States  2018     242675.896838
# 3521  United States  2019     234567.608105
#
# [160 rows x 3 columns]
